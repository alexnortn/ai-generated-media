# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive'                                              # default for the drive
PROJ = 'My Drive/Colab Notebooks/Experiments in AI Generated Media/' # path to your project on Drive

GIT_USERNAME = "alexnortn"                                           # replace with yours
GIT_TOKEN = "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"               # definitely replace with yours
GIT_REPOSITORY = "ai-generated-media"                                # ...nah


drive.mount(ROOT)           # we mount the drive at /content/drive

PROJECT_PATH = join(ROOT, PROJ)
# !mkdir "{PROJECT_PATH}"    # in case we haven't created it already   

GIT_PATH = f"https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"
# !mkdir ./temp
# !git clone "{GIT_PATH}"
# !mv ./temp/* "{PROJECT_PATH}"
# !rm -rf ./temp
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/*  ./
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# mkdir: cannot create directory ‘/content/drive/My Drive/Colab Notebooks/Experiments in AI Generated Media/’: File exists
# fatal: destination path 'ai-generated-media' already exists and is not an empty directory.
# mv: cannot stat './temp/*': No such file or directory
# sending incremental file list
# Experiments in Synthetic Media_Experiment 1
#          36,983 100%    4.02MB/s    0:00:00 (xfr#1, to-chk=1/2)
# git.ipynb
#           4,784 100%    5.91kB/s    0:00:00 (xfr#2, to-chk=0/2)

# %%
from google.colab import drive
from os.path import join

ROOT = '/content/drive'                                              # default for the drive
PROJ = 'My Drive/Colab Notebooks/Experiments in AI Generated Media/' # path to your project on Drive
PROJECT_PATH = join(ROOT, PROJ)

GIT_USERNAME = "alexnortn"                                           # replace with yours
GIT_TOKEN = "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"               # definitely replace with yours
GIT_REPOSITORY = "ai-generated-media"                                # ...nah
GIT_PATH = f"https://{GIT_TOKEN}@github.com/{GIT_USERNAME}/{GIT_REPOSITORY}.git"

# !mkdir ./temp
# !git clone "{GIT_PATH}" ./temp
# !rsync -aP --exclude=data/ "{PROJECT_PATH}"/* ./temp

# %cd ./temp
# !git add .
# !git commit -m '"Test commit"'
# !git config --global user.email "alexnortn@gmail.com"
# !git config --global user.name "alexnortn"
# !git push origin "main"
# %cd /content
# !rm -rf ./temp
# Out:
# Cloning into './temp'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 82 (delta 31), reused 53 (delta 14), pack-reused 0
# Unpacking objects: 100% (82/82), done.
# sending incremental file list
# Experiments in Synthetic Media_Experiment 1
#          36,983 100%    4.02MB/s    0:00:00 (xfr#1, to-chk=1/2)
# git.ipynb
#           4,515 100%    3.09kB/s    0:00:01 (xfr#2, to-chk=0/2)
# /content/temp
# [main 402ecdf] "Test commit"
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite Experiments in Synthetic Media_Experiment 1 (96%)
#  rewrite git.ipynb (98%)
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 825 bytes | 825.00 KiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# ...
